# %% [markdown]
# 1) Faça um algoritmo que leia os valores A, B, C e imprima na tela se a soma de A + B é menor que C.

# %%
a = int(input("Qual valor de A:"))
b = int(input("Qual valor de B:"))
c = int(input("Qual valor de C:"))

if a + b > c:
    print("A + B MAIOR QUE C")
else:
    print("C MAIOR")
# Out:
# Qual valor de A:14
# Qual valor de B:15
# Qual valor de C:20
# A + B MAIOR QUE C

# %% [markdown]
# 2) Faça um algoritmo que leia o nome, o sexo e o estado civil de uma pessoa. Caso sexo seja “F” e estado civil seja “CASADA”, solicitar o tempo de casada (anos).

# %%
nome = input("Qual seu nome:")
mulher = input("vc é mulher: ")
estadoCivil = input("Casado(a)?: ")

if mulher == "sim" and estadoCivil == "sim":
    tempodeCasada = input("A quando tempo(anos)?: ")
    print("Voce é casada a ", tempodeCasada, "anos")
else:
    print("Voce é homem")
# Out:
# Qual seu nome:Ana
# vc é mulher: Sim
# Casado(a)?: Não
# Voce é homem

# %% [markdown]
# 3) Faça um algoritmo para receber um número qualquer e informar na tela se é par ou ímpar.

# %%
num_str = input("Digite qualquer número: ")

try:
    num = int(num_str)

    if num % 2 == 0:
        print("Você digitou um número par!")
    else:
        print("Você digitou um número ímpar!")
except ValueError:
    print("Por favor, digite um número válido.")
# Out:
# Digite qualquer número: 9
# Você digitou um número ímpar!

# %% [markdown]
# 4) Faça um algoritmo que leia dois valores inteiros A e B se os valores forem iguais deverá se
# somar os dois, caso contrário multiplique A por B. Ao final de qualquer um dos cálculos deve-se
# atribuir o resultado para uma variável C e mostrar seu conteúdo na tela.

# %%
A = int(input("Digite o valor de A: "))
B = int(input("Digite o valor de B: "))


if A == B:
    C = A + B
else:
    C = A * B

print("O valor de C é:", C)
# Out:
# Digite o valor de A: 3
# Digite o valor de B: 3
# O valor de C é: 6

# %% [markdown]
# 5) Encontrar o dobro de um número caso ele seja positivo e o seu triplo caso seja negativo,
# imprimindo o resultado.

# %%
def calcular_valor(numero):
    if numero > 0:
        return numero * 2
    else:
        return numero * 3

numero = float(input("Digite um número: "))
resultado = calcular_valor(numero)
print("Resultado:", resultado)
# Out:
# Digite um número: 20
# Resultado: 40.0

# %% [markdown]
# 6) Escreva um algoritmo que lê dois valores booleanos (lógicos) e então determina se ambos são
# VERDADEIROS ou FALSOS.

# %%
def verificar_booleanos(valor1, valor2):
    if valor1 == True and valor2 == True:
        return "Ambos são VERDADEIROS"
    elif valor1 == False and valor2 == False:
        return "Ambos são FALSOS"
    else:
        return "Um é VERDADEIRO e o outro é FALSO"

valor1 = input("Digite o primeiro valor booleano (True/False): ").strip().lower() == 'true'
valor2 = input("Digite o segundo valor booleano (True/False): ").strip().lower() == 'true'

resultado = verificar_booleanos(valor1, valor2)
print("Resultado:", resultado)
# Out:
# Digite o primeiro valor booleano (True/False): 20
# Digite o segundo valor booleano (True/False): 30
# Resultado: Ambos são FALSOS

# %% [markdown]
# 7) Faça um algoritmo que leia uma variável e some 5 caso seja par ou some 8 caso seja ímpar,
# imprimir o resultado desta operação.

# %%
def somar_par_ou_impar(numero):
    if numero % 2 == 0:
        return numero + 5
    else:
        return numero + 8

try:
    numero = int(input("Digite um número: "))
    resultado = somar_par_ou_impar(numero)
    print("Resultado:", resultado)
except ValueError:
    print("Por favor, insira um valor numérico inteiro válido.")
# Out:
# Digite um número: 3
# Resultado: 11

# %% [markdown]
# 8) Escreva um algoritmo que leia três valores inteiros e diferentes e mostre-os em ordem
# decrescente.

# %%
def ordenar_decrescente(a, b, c):
    numeros = [a, b, c]
    numeros.sort(reverse=True)
    return numeros

try:
    a = int(input("Digite o primeiro número inteiro: "))
    b = int(input("Digite o segundo número inteiro: "))
    c = int(input("Digite o terceiro número inteiro: "))

    if a != b and b != c and a != c:
        resultado = ordenar_decrescente(a, b, c)
        print("Números em ordem decrescente:", resultado)
    else:
        print("Os números devem ser diferentes.")
except ValueError:
    print("Por favor, insira apenas números inteiros.")
# Out:
# Digite o primeiro número inteiro: 10
# Digite o segundo número inteiro: 20
# Digite o terceiro número inteiro: 30
# Números em ordem decrescente: [30, 20, 10]

# %% [markdown]
# 9) Tendo como dados de entrada a altura e o sexo de uma pessoa, construa um algoritmo que
# calcule seu peso ideal, utilizando as seguintes fórmulas:
# ● para homens: (72.7 * h) – 58;
# ● para mulheres: (62.1 * h) – 44.7.

# %%
def calcular_peso_ideal(altura, sexo):
    if sexo.lower() == 'homem':
        return (72.7 * altura) - 58
    elif sexo.lower() == 'mulher':
        return (62.1 * altura) - 44.7
    else:
        return None

try:
    altura = float(input("Digite a altura em metros (ex: 1.75): "))
    sexo = input("Digite o sexo (homem/mulher): ").strip().lower()

    peso_ideal = calcular_peso_ideal(altura, sexo)

    if peso_ideal is not None:
        print(f"O peso ideal para uma pessoa do sexo {sexo} com altura {altura:.2f} m é: {peso_ideal:.2f} kg")
    else:
        print("Sexo inválido! Por favor, digite 'homem' ou 'mulher'.")
except ValueError:
    print("Por favor, insira valores numéricos válidos para a altura.")
# Out:
# Digite a altura em metros (ex: 1.75): 1.73
# Digite o sexo (homem/mulher): mulher
# O peso ideal para uma pessoa do sexo mulher com altura 1.73 m é: 62.73 kg

# %% [markdown]
# 10) O IMC – Indice de Massa Corporal é um critério da Organização Mundial de Saúde para dar
# umaindicação sobre a condição de peso de uma pessoa adulta. A fórmula é IMC = peso / ( altura )2
#
# Elabore um algoritmo que leia o peso e a altura de um adulto e mostre sua condição de acordo
# com a tabela abaixo.
# IMC em adultos Condição
# Abaixo de 18,5 Abaixo do peso
# Entre 18,5 e 25 Peso normal
# Entre 25 e 30 Acima do peso
# Acima de 30 obeso

# %%
def calcular_imc(peso, altura):
    return peso / (altura ** 2)

def classificar_imc(imc):
    if imc < 18.5:
        return "Abaixo do peso"
    elif 18.5 <= imc < 25:
        return "Peso normal"
    elif 25 <= imc < 30:
        return "Acima do peso"
    else:
        return "Obeso"

try:
    peso = float(input("Digite o seu peso em kg: "))
    altura = float(input("Digite a sua altura em metros (ex: 1.75): "))

    imc = calcular_imc(peso, altura)
    classificacao = classificar_imc(imc)

    print(f"Seu IMC é: {imc:.2f}")
    print(f"Condição: {classificacao}")
except ValueError:
    print("Por favor, insira valores numéricos válidos para peso e altura.")
# Out:
# Digite o seu peso em kg: 88
# Digite a sua altura em metros (ex: 1.75): 1.73
# Seu IMC é: 29.40
# Condição: Acima do peso

# %% [markdown]
# 11) Elabore um algoritmo que calcule o que deve ser pago por um produto, considerando o preço
# normal deetiqueta e a escolha da condição de pagamento. Utilize os códigos da tabela a seguir
# para ler qual acondição de pagamento escolhida e efetuar o cálculo adequado.
# Código Condição de pagamento
# 1 À vista em dinheiro ou cheque, recebe 10% de desconto
# 2 À vista no cartão de crédito, recebe 15% de desconto
# 3 Em duas vezes, preço normal de etiqueta sem juros
# 4 Em duas vezes, preço normal de etiqueta mais juros de 10%

# %%
def calcular_preco_final(preco, condicao):
    if condicao == 1:
        desconto = 10
        preco_final = preco * (1 - desconto / 100)
    elif condicao == 2:
        desconto = 15
        preco_final = preco * (1 - desconto / 100)
    elif condicao == 3:
        preco_final = preco
    elif condicao == 4:
        juros = 10
        preco_final = preco * (1 + juros / 100)
    else:
        return None
    return preco_final


preco = float(input("Digite o preço do produto: R$ "))
condicao = int(input("Condição de pagamento (1: à vista dinheiro/cheque, 2: à vista cartão, 3: duas vezes sem juros, 4: duas vezes com juros): "))


preco_final = calcular_preco_final(preco, condicao)

if preco_final is not None:
    print(f"O valor a ser pago é: R$ {preco_final:.2f}")
else:
    print("Condição de pagamento inválida.")
# Out:
# Digite o preço do produto: R$ 400
# Condição de pagamento (1: à vista dinheiro/cheque, 2: à vista cartão, 3: duas vezes sem juros, 4: duas vezes com juros): 4
# O valor a ser pago é: R$ 440.00

# %% [markdown]
# 12) Escreva um algoritmo que leia o número de identificação, as 3 notas obtidas por um aluno nas
# 3 verificações e a média dos exercícios que fazem parte da avaliação, e calcule a média de
# aproveitamento, usando a fórmula:
# MA := (nota1 + nota 2 * 2 + nota 3 * 3 + ME)/7
# A atribuição dos conceitos obedece a tabela abaixo. O algoritmo deve escrever o número do aluno,
# suas notas, a média dos exercícios, a média de aproveitamento, o conceito correspondente e a
# mensagem 'Aprovado' se o conceito for A, B ou C, e 'Reprovado' se o conceito for D ou E.
# Média de aproveitamento Conceito
# >= 90 A
# >= 75 e < 90 B
# >= 60 e < 75 C
# >= 40 e < 60 D
# < 40 E

# %%
def calcular_media_aproveitamento(nota1, nota2, nota3, media_exercicios):
    return (nota1 + nota2 * 2 + nota3 * 3 + media_exercicios) / 7

def determinar_conceito(media):
    if media >= 90:
        return 'A'
    elif media >= 75:
        return 'B'
    elif media >= 60:
        return 'C'
    elif media >= 40:
        return 'D'
    else:
        return 'E'

def verificar_status(conceito):
    return "Aprovado" if conceito in ['A', 'B', 'C'] else "Reprovado"


numero_identificacao = input("Digite o número de identificação do aluno: ")
nota1 = float(input("Digite a nota 1: "))
nota2 = float(input("Digite a nota 2: "))
nota3 = float(input("Digite a nota 3: "))
media_exercicios = float(input("Digite a média dos exercícios: "))


media_aproveitamento = calcular_media_aproveitamento(nota1, nota2, nota3, media_exercicios)
conceito = determinar_conceito(media_aproveitamento)
status = verificar_status(conceito)


print(f"\nNúmero de Identificação: {numero_identificacao}")
print(f"Nota 1: {nota1:.2f}")
print(f"Nota 2: {nota2:.2f}")
print(f"Nota 3: {nota3:.2f}")
print(f"Média dos Exercícios: {media_exercicios:.2f}")
print(f"Média de Aproveitamento: {media_aproveitamento:.2f}")
print(f"Conceito: {conceito}")
print(f"Status: {status}")
# Out:
# Digite o número de identificação do aluno: 2324
# Digite a nota 1: 8
# Digite a nota 2: 2
# Digite a nota 3: 5
# Digite a média dos exercícios: 5
#
# Número de Identificação: 2324
# Nota 1: 8.00
# Nota 2: 2.00
# Nota 3: 5.00
# Média dos Exercícios: 5.00
# Média de Aproveitamento: 4.57
# Conceito: E
# Status: Reprovado
